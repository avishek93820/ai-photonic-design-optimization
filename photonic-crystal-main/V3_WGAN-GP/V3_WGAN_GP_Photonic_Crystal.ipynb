# %%
# IMPORTS
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets

from torchvision import transforms
from torchvision.utils import save_image
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

torch.manual_seed(42)
np.random.seed(42)
torch.backends.cudnn.benchmark = True

# CONFIG

DEVICE         = "cuda" if torch.cuda.is_available() else "cpu"
IMG_SIZE       = 256    
IMG_CHANNELS   = 1
BATCH_SIZE     = 4          
NOISE_DIM      = 128
FEATURE_GEN    = 32
FEATURE_CRITIC = 32
LR             = 5e-5
EPOCHS         = 300
CRITIC_ITER    = 5
LAMBDA_GP      = 10

print(f"DEVICE: {DEVICE}")
print(f"IMG_SIZE: {IMG_SIZE}x{IMG_SIZE}")

# PREPROCESSING

INPUT_FOLDER  = "photonic_images/classA"
OUTPUT_FOLDER = "processed_photonic/classA"

os.makedirs(OUTPUT_FOLDER, exist_ok=True)

for file in os.listdir(INPUT_FOLDER):

    path = os.path.join(INPUT_FOLDER, file)
    img  = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

    if img is None:
        print(f"Warning: Could not read {file}, skipping.")
        continue

    img = cv2d = cv2.resize(img, (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_LANCZOS4)

    cv2.imwrite(os.path.join(OUTPUT_FOLDER, file), img)

print("Preprocessing complete. Sharp images saved.")

# VERIFY PREPROCESSED IMAGES

files = os.listdir(OUTPUT_FOLDER)

fig, axes = plt.subplots(2, 4, figsize=(14, 7))

for i, ax in enumerate(axes.flatten()):
    if i >= len(files):
        ax.axis("off")
        continue
    img = cv2.imread(os.path.join(OUTPUT_FOLDER, files[i]), cv2.IMREAD_GRAYSCALE)
    ax.imshow(img, cmap="gray")
    ax.set_title(files[i][:15], fontsize=7)
    ax.axis("off")

plt.suptitle("Preprocessed Photonic Images (Sharp, No Blur)", fontsize=14)
plt.tight_layout()
plt.show()

# TRANSFORMS

transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5]) 
])

# DATASET

dataset = datasets.ImageFolder(
    root="processed_photonic",
    transform=transform
)

loader = DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    pin_memory=True,
    num_workers=2,
    drop_last=True
)

print(f"Dataset size: {len(dataset)} images")

# GENERATOR
class Generator(nn.Module):

    def __init__(self, noise_dim, channels_img, features_g):
        super().__init__()

        self.net = nn.Sequential(

            # 1x1 -> 4x4
            self._block(noise_dim, features_g * 32, 4, 1, 0),

            # 4x4 -> 8x8
            self._block(features_g * 32, features_g * 16, 4, 2, 1),

            # 8x8 -> 16x16
            self._block(features_g * 16, features_g * 8, 4, 2, 1),

            # 16x16 -> 32x32
            self._block(features_g * 8, features_g * 4, 4, 2, 1),

            # 32x32 -> 64x64
            self._block(features_g * 4, features_g * 2, 4, 2, 1),

            # 64x64 -> 128x128
            self._block(features_g * 2, features_g, 4, 2, 1),

            # 128x128 -> 256x256  
            nn.ConvTranspose2d(
                features_g,
                channels_img,
                kernel_size=4,
                stride=2,
                padding=1,
                bias=False
            ),

            nn.Tanh()
        )

    def _block(self, in_c, out_c, kernel, stride, pad):
        return nn.Sequential(
            nn.ConvTranspose2d(in_c, out_c, kernel, stride, pad, bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(True)
        )

    def forward(self, x):
        x = x.view(x.shape[0], x.shape[1], 1, 1)
        return self.net(x)

# CRITIC

class Critic(nn.Module):

    def __init__(self, channels_img, features_d):
        super().__init__()

        self.net = nn.Sequential(

            # 256x256 -> 128x128
            nn.Conv2d(channels_img, features_d, 4, 2, 1),
            nn.LeakyReLU(0.2),

            # 128x128 -> 64x64
            self._block(features_d,      features_d * 2),

            # 64x64 -> 32x32
            self._block(features_d * 2,  features_d * 4),

            # 32x32 -> 16x16
            self._block(features_d * 4,  features_d * 8),

            # 16x16 -> 8x8
            self._block(features_d * 8,  features_d * 16),

            # 8x8 -> 4x4
            self._block(features_d * 16, features_d * 32),

            # 4x4 -> 1x1
            nn.Conv2d(features_d * 32, 1, kernel_size=4, stride=1, padding=0)
        )

    def _block(self, in_c, out_c):
        return nn.Sequential(
            nn.Conv2d(in_c, out_c, 4, 2, 1, bias=False),
            nn.InstanceNorm2d(out_c, affine=True),
            nn.LeakyReLU(0.2)
        )

    def forward(self, x):
        return self.net(x).reshape(-1)

# WEIGHT INIT

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        if isinstance(m, nn.BatchNorm2d):
            nn.init.normal_(m.weight.data, 1.0, 0.02)
            nn.init.constant_(m.bias.data, 0)

# GRADIENT PENALTY

def gradient_penalty(critic, real, fake, device):

    B, C, H, W = real.shape

    epsilon = torch.rand(B, 1, 1, 1).repeat(1, C, H, W).to(device)

    interpolated = real * epsilon + fake * (1 - epsilon)
    interpolated.requires_grad_(True)

    mixed_scores = critic(interpolated)

    gradient = torch.autograd.grad(
        inputs=interpolated,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True
    )[0]

    gradient      = gradient.reshape(B, -1)
    gradient_norm = gradient.norm(2, dim=1)
    gp            = torch.mean((gradient_norm - 1) ** 2)

    return gp


# INIT MODELS

gen    = Generator(NOISE_DIM, IMG_CHANNELS, FEATURE_GEN).to(DEVICE)
critic = Critic(IMG_CHANNELS, FEATURE_CRITIC).to(DEVICE)

initialize_weights(gen)
initialize_weights(critic)

opt_gen    = optim.Adam(gen.parameters(),    lr=LR, betas=(0.0, 0.9))
opt_critic = optim.Adam(critic.parameters(), lr=LR, betas=(0.0, 0.9))

fixed_noise = torch.randn(16, NOISE_DIM).to(DEVICE)

print(f"Generator params:  {sum(p.numel() for p in gen.parameters()):,}")
print(f"Critic params:     {sum(p.numel() for p in critic.parameters()):,}")

# TENSORBOARD

writer_real = SummaryWriter("logs/real")
writer_fake = SummaryWriter("logs/fake")

step = 0

# CHECKPOINT SETUP

os.makedirs("checkpoints", exist_ok=True)
best_critic_loss = float("-inf")

# TRAINING LOOP

gen.train()
critic.train()

for epoch in range(EPOCHS):

    epoch_critic_loss = 0

    for batch_idx, (real, _) in enumerate(loader):

        real          = real.to(DEVICE)
        cur_batch     = real.shape[0]

        # ---- TRAIN CRITIC ----
        for _ in range(CRITIC_ITER):

            noise        = torch.randn(cur_batch, NOISE_DIM).to(DEVICE)
            fake         = gen(noise)

            critic_real  = critic(real)
            critic_fake  = critic(fake.detach())

            gp           = gradient_penalty(critic, real, fake.detach(), DEVICE)

            loss_critic  = -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp

            critic.zero_grad()
            loss_critic.backward()
            opt_critic.step()

        epoch_critic_loss += loss_critic.item()

        # ---- TRAIN GENERATOR ----
        noise     = torch.randn(cur_batch, NOISE_DIM).to(DEVICE)
        fake      = gen(noise)
        gen_fake  = critic(fake)
        loss_gen  = -torch.mean(gen_fake)

        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

    # ---- LOGGING ----
    avg_critic = epoch_critic_loss / len(loader)

    print(
        f"Epoch [{epoch+1:03d}/{EPOCHS}] "
        f"Critic: {loss_critic:.4f}  "
        f"Gen: {loss_gen:.4f}  "
        f"Avg Critic: {avg_critic:.4f}"
    )

    # ---- TENSORBOARD + CHECKPOINT every 10 epochs ----
    if (epoch + 1) % 10 == 0:

        with torch.no_grad():

            fake_samples = gen(fixed_noise)
            fake_samples = fake_samples * 0.5 + 0.5 

            real_grid = torchvision.utils.make_grid(real[:4], normalize=True)
            fake_grid = torchvision.utils.make_grid(fake_samples[:4], normalize=True)

            writer_real.add_image("Real", real_grid, global_step=step)
            writer_fake.add_image("Fake", fake_grid, global_step=step)
            step += 1

        # Saving checkpoint if critic loss improved (less negative = better convergence)
        if avg_critic > best_critic_loss:
            best_critic_loss = avg_critic
            torch.save({
                "epoch":            epoch,
                "gen_state":        gen.state_dict(),
                "critic_state":     critic.state_dict(),
                "opt_gen_state":    opt_gen.state_dict(),
                "opt_critic_state": opt_critic.state_dict(),
                "critic_loss":      avg_critic
            }, "checkpoints/best_model.pt")
            print(f"  -> Checkpoint saved at epoch {epoch+1} (critic loss: {avg_critic:.4f})")

# saving final model
torch.save({
    "epoch":        EPOCHS,
    "gen_state":    gen.state_dict(),
    "critic_state": critic.state_dict(),
}, "checkpoints/final_model.pt")

print("Training complete.")

# GENERATE & SAVE

os.makedirs("generated_images", exist_ok=True)

gen.eval()

with torch.no_grad():

    noise       = torch.randn(200, NOISE_DIM).to(DEVICE)
    fake_images = gen(noise)
    fake_images = (fake_images * 0.5 + 0.5).clamp(0, 1)

    for i in range(200):
        save_image(fake_images[i], f"generated_images/generated_{i}.png")

print("200 images saved to generated_images/")

# VISUALIZE
gen.eval()

with torch.no_grad():
    noise   = torch.randn(16, NOISE_DIM).to(DEVICE)
    samples = gen(noise)
    samples = (samples * 0.5 + 0.5).clamp(0, 1)

fig, axes = plt.subplots(4, 4, figsize=(12, 12))

for i, ax in enumerate(axes.flatten()):
    ax.imshow(samples[i].cpu().squeeze(), cmap="gray")
    ax.axis("off")

plt.suptitle("WGAN-GP Generated Photonic Crystals (256x256)", fontsize=16)
plt.tight_layout()
plt.savefig("generated_images/sample_grid.png", dpi=150, bbox_inches="tight")
plt.show()
print("Sample grid saved.")
# Out:
# DEVICE: cuda
# IMG_SIZE: 256x256
# Preprocessing complete. Sharp images saved.
# Dataset size: 34 images
# Generator params:  13,275,584
# Critic params:     11,194,785
# Epoch [001/300] Critic: 7.3904  Gen: 0.8459  Avg Critic: 825.3502
# Epoch [002/300] Critic: -29.9429  Gen: 16.2887  Avg Critic: 6.2965
# Epoch [003/300] Critic: -102.0247  Gen: 47.0573  Avg Critic: -66.0244
# Epoch [004/300] Critic: -135.5675  Gen: 66.1614  Avg Critic: -122.5847
# Epoch [005/300] Critic: -155.9403  Gen: 78.9234  Avg Critic: -143.0139
# Epoch [006/300] Critic: -153.0857  Gen: 77.4369  Avg Critic: -141.8142
# Epoch [007/300] Critic: -117.3130  Gen: 77.0167  Avg Critic: -141.1084
# Epoch [008/300] Critic: -124.7059  Gen: 76.6827  Avg Critic: -131.8741
# Epoch [009/300] Critic: -121.6176  Gen: 71.1768  Avg Critic: -125.2637
# Epoch [010/300] Critic: -123.4898  Gen: 70.9792  Avg Critic: -116.1560
#   -> Checkpoint saved at epoch 10 (critic loss: -116.1560)
# Epoch [011/300] Critic: -159.6629  Gen: 76.5363  Avg Critic: -123.9030
# Epoch [012/300] Critic: -118.3675  Gen: 62.7309  Avg Critic: -117.1893
# Epoch [013/300] Critic: -113.9142  Gen: 59.2462  Avg Critic: -117.9873
# Epoch [014/300] Critic: -107.6924  Gen: 73.0425  Avg Critic: -119.8818
# Epoch [015/300] Critic: -107.6355  Gen: 59.9316  Avg Critic: -114.5132
# Epoch [016/300] Critic: -114.8880  Gen: 66.0609  Avg Critic: -117.1283
# Epoch [017/300] Critic: -119.6130  Gen: 67.8594  Avg Critic: -113.5278
# Epoch [018/300] Critic: -127.9223  Gen: 70.4749  Avg Critic: -115.1392
# Epoch [019/300] Critic: -116.1796  Gen: 78.6009  Avg Critic: -114.0538
# Epoch [020/300] Critic: -111.8814  Gen: 45.5189  Avg Critic: -112.4244
#   -> Checkpoint saved at epoch 20 (critic loss: -112.4244)
# Epoch [021/300] Critic: -113.7044  Gen: 73.7991  Avg Critic: -110.3956
# Epoch [022/300] Critic: -114.1329  Gen: 67.0010  Avg Critic: -110.9083
# Epoch [023/300] Critic: -117.4448  Gen: 36.0145  Avg Critic: -104.7596
# Epoch [024/300] Critic: -112.7668  Gen: 60.3057  Avg Critic: -113.5765
# Epoch [025/300] Critic: -102.5104  Gen: 67.5403  Avg Critic: -105.5943
# Epoch [026/300] Critic: -101.9809  Gen: 69.8128  Avg Critic: -103.9571
# Epoch [027/300] Critic: -94.4623  Gen: 66.1207  Avg Critic: -97.4321
# Epoch [028/300] Critic: -102.9572  Gen: 41.2539  Avg Critic: -99.7095
# Epoch [029/300] Critic: -85.0383  Gen: 53.4399  Avg Critic: -90.6207
# Epoch [030/300] Critic: -95.7589  Gen: 50.2360  Avg Critic: -88.0679
#   -> Checkpoint saved at epoch 30 (critic loss: -88.0679)
# Epoch [031/300] Critic: -87.9016  Gen: 19.6663  Avg Critic: -89.2751
# Epoch [032/300] Critic: -74.9815  Gen: 43.4958  Avg Critic: -82.1125
# Epoch [033/300] Critic: -75.1479  Gen: 34.6973  Avg Critic: -79.8805
# Epoch [034/300] Critic: -64.4892  Gen: 52.3365  Avg Critic: -80.3993
# Epoch [035/300] Critic: -67.2895  Gen: 41.5199  Avg Critic: -78.7415
# Epoch [036/300] Critic: -88.2085  Gen: 22.4050  Avg Critic: -76.4099
# Epoch [037/300] Critic: -75.4321  Gen: 28.3346  Avg Critic: -70.7139
# Epoch [038/300] Critic: -61.5040  Gen: 28.6473  Avg Critic: -67.4204
# Epoch [039/300] Critic: -92.7634  Gen: 10.6046  Avg Critic: -72.1878
# Epoch [040/300] Critic: -55.3519  Gen: 34.0506  Avg Critic: -65.6166
#   -> Checkpoint saved at epoch 40 (critic loss: -65.6166)
# Epoch [041/300] Critic: -80.4883  Gen: -12.0098  Avg Critic: -75.5098
# Epoch [042/300] Critic: -63.9054  Gen: 25.8596  Avg Critic: -71.0364
# Epoch [043/300] Critic: -71.9206  Gen: 36.3617  Avg Critic: -66.1621
# Epoch [044/300] Critic: -61.5728  Gen: 18.6426  Avg Critic: -66.1732
# Epoch [045/300] Critic: -60.4320  Gen: 0.1520  Avg Critic: -64.1244
# Epoch [046/300] Critic: -66.1275  Gen: 17.3861  Avg Critic: -63.7582
# Epoch [047/300] Critic: -58.6274  Gen: 10.0362  Avg Critic: -63.3380
# Epoch [048/300] Critic: -62.3703  Gen: 39.0875  Avg Critic: -60.0461
# Epoch [049/300] Critic: -57.7919  Gen: 34.7168  Avg Critic: -62.1859
# Epoch [050/300] Critic: -57.5514  Gen: 24.9594  Avg Critic: -58.4663
#   -> Checkpoint saved at epoch 50 (critic loss: -58.4663)
# Epoch [051/300] Critic: -64.6625  Gen: 29.6327  Avg Critic: -60.8330
# Epoch [052/300] Critic: -63.2143  Gen: 24.1155  Avg Critic: -60.3615
# Epoch [053/300] Critic: -54.0121  Gen: 38.0661  Avg Critic: -57.2357
# Epoch [054/300] Critic: -53.1401  Gen: 42.5557  Avg Critic: -56.2466
# Epoch [055/300] Critic: -51.1024  Gen: 11.2058  Avg Critic: -56.2799
# Epoch [056/300] Critic: -57.6031  Gen: 3.5285  Avg Critic: -56.5957
# Epoch [057/300] Critic: -48.6363  Gen: 40.0160  Avg Critic: -56.1079
# Epoch [058/300] Critic: -58.5344  Gen: 34.2799  Avg Critic: -54.6581
# Epoch [059/300] Critic: -45.4481  Gen: 44.7386  Avg Critic: -55.6756
# Epoch [060/300] Critic: -50.6083  Gen: 14.1518  Avg Critic: -55.7333
#   -> Checkpoint saved at epoch 60 (critic loss: -55.7333)
# Epoch [061/300] Critic: -64.6966  Gen: 35.4427  Avg Critic: -52.5500
# Epoch [062/300] Critic: -53.8966  Gen: 31.7056  Avg Critic: -53.6206
# Epoch [063/300] Critic: -52.5369  Gen: 23.7176  Avg Critic: -53.2260
# Epoch [064/300] Critic: -56.2209  Gen: 39.9701  Avg Critic: -55.2206
# Epoch [065/300] Critic: -45.4203  Gen: 25.5773  Avg Critic: -50.3454
# Epoch [066/300] Critic: -67.1145  Gen: 49.8587  Avg Critic: -53.2025
# Epoch [067/300] Critic: -49.5587  Gen: 51.3265  Avg Critic: -50.9912
# Epoch [068/300] Critic: -46.3034  Gen: 38.6542  Avg Critic: -51.0487
# Epoch [069/300] Critic: -45.9910  Gen: 47.2230  Avg Critic: -50.1431
# Epoch [070/300] Critic: -73.9393  Gen: 55.4794  Avg Critic: -56.0456
# Epoch [071/300] Critic: -58.1306  Gen: 41.9734  Avg Critic: -53.6904
# Epoch [072/300] Critic: -54.0771  Gen: 46.3109  Avg Critic: -52.1043
# Epoch [073/300] Critic: -55.9832  Gen: 39.6102  Avg Critic: -54.9194
# Epoch [074/300] Critic: -54.6636  Gen: 46.2003  Avg Critic: -48.9811
# Epoch [075/300] Critic: -44.2968  Gen: 42.9517  Avg Critic: -51.4890
# Epoch [076/300] Critic: -45.3513  Gen: 35.6078  Avg Critic: -50.4703
# Epoch [077/300] Critic: -51.9274  Gen: 63.9318  Avg Critic: -51.1205
# Epoch [078/300] Critic: -41.0311  Gen: 42.4497  Avg Critic: -48.2328
# Epoch [079/300] Critic: -38.6016  Gen: 64.1163  Avg Critic: -50.3059
# Epoch [080/300] Critic: -61.7846  Gen: 43.2984  Avg Critic: -48.7360
#   -> Checkpoint saved at epoch 80 (critic loss: -48.7360)
# Epoch [081/300] Critic: -59.6288  Gen: 47.1088  Avg Critic: -49.6400
# Epoch [082/300] Critic: -46.0069  Gen: 41.2704  Avg Critic: -49.0584
# Epoch [083/300] Critic: -41.8860  Gen: 31.4422  Avg Critic: -49.4422
# Epoch [084/300] Critic: -51.0949  Gen: 48.4436  Avg Critic: -49.2433
# Epoch [085/300] Critic: -46.2669  Gen: 41.2399  Avg Critic: -47.4209
# Epoch [086/300] Critic: -57.8059  Gen: 58.0952  Avg Critic: -50.6937
# Epoch [087/300] Critic: -52.7756  Gen: 63.1214  Avg Critic: -51.3495
# Epoch [088/300] Critic: -42.2742  Gen: 71.5130  Avg Critic: -45.7614
# Epoch [089/300] Critic: -47.6330  Gen: 55.2929  Avg Critic: -48.7327
# Epoch [090/300] Critic: -42.8232  Gen: 59.8497  Avg Critic: -49.1512
# Epoch [091/300] Critic: -50.2857  Gen: 49.8235  Avg Critic: -46.7312
# Epoch [092/300] Critic: -53.9765  Gen: 54.6397  Avg Critic: -49.6256
# Epoch [093/300] Critic: -57.4451  Gen: 49.0688  Avg Critic: -50.7611
# Epoch [094/300] Critic: -43.6971  Gen: 36.7350  Avg Critic: -50.6463
# Epoch [095/300] Critic: -44.6694  Gen: 44.2123  Avg Critic: -47.5356
# Epoch [096/300] Critic: -47.8258  Gen: 48.9405  Avg Critic: -47.2586
# Epoch [097/300] Critic: -43.1583  Gen: 29.5803  Avg Critic: -44.7833
# Epoch [098/300] Critic: -69.5640  Gen: 42.5184  Avg Critic: -47.5582
# Epoch [099/300] Critic: -42.5919  Gen: 52.9038  Avg Critic: -44.2533
# Epoch [100/300] Critic: -43.7298  Gen: 50.2408  Avg Critic: -46.3425
#   -> Checkpoint saved at epoch 100 (critic loss: -46.3425)
# Epoch [101/300] Critic: -41.1399  Gen: 49.4752  Avg Critic: -46.8527
# Epoch [102/300] Critic: -43.8309  Gen: 63.0006  Avg Critic: -50.0392
# Epoch [103/300] Critic: -49.7487  Gen: 33.1199  Avg Critic: -48.4068
# Epoch [104/300] Critic: -44.8191  Gen: 39.7198  Avg Critic: -48.6890
# Epoch [105/300] Critic: -47.2262  Gen: 54.9237  Avg Critic: -47.2378
# Epoch [106/300] Critic: -41.8804  Gen: 48.6110  Avg Critic: -43.1861
# Epoch [107/300] Critic: -42.2045  Gen: 57.2752  Avg Critic: -43.8219
# Epoch [108/300] Critic: -39.1599  Gen: 61.3842  Avg Critic: -48.9509
# Epoch [109/300] Critic: -35.8141  Gen: 54.3729  Avg Critic: -46.2054
# Epoch [110/300] Critic: -38.3199  Gen: 62.0919  Avg Critic: -43.5560
#   -> Checkpoint saved at epoch 110 (critic loss: -43.5560)
# Epoch [111/300] Critic: -40.5415  Gen: 56.2112  Avg Critic: -48.6968
# Epoch [112/300] Critic: -52.2403  Gen: 63.8063  Avg Critic: -45.3818
# Epoch [113/300] Critic: -42.2621  Gen: 47.0303  Avg Critic: -45.4090
# Epoch [114/300] Critic: -43.2486  Gen: 32.1978  Avg Critic: -46.4406
# Epoch [115/300] Critic: -59.2791  Gen: 55.5378  Avg Critic: -48.2256
# Epoch [116/300] Critic: -41.7216  Gen: 64.2594  Avg Critic: -47.1898
# Epoch [117/300] Critic: -53.2193  Gen: 38.2021  Avg Critic: -49.6782
# Epoch [118/300] Critic: -48.6481  Gen: 33.2485  Avg Critic: -44.7868
# Epoch [119/300] Critic: -38.8390  Gen: 47.3088  Avg Critic: -46.3644
# Epoch [120/300] Critic: -40.8612  Gen: 42.8983  Avg Critic: -45.4924
# Epoch [121/300] Critic: -57.5052  Gen: 71.5774  Avg Critic: -48.0728
# Epoch [122/300] Critic: -78.1619  Gen: 31.2963  Avg Critic: -44.0515
# Epoch [123/300] Critic: -61.4237  Gen: 64.5027  Avg Critic: -46.4135
# Epoch [124/300] Critic: -50.9748  Gen: 51.1423  Avg Critic: -47.0281
# Epoch [125/300] Critic: -41.8142  Gen: 56.6235  Avg Critic: -48.0677
# Epoch [126/300] Critic: -53.5188  Gen: 47.3399  Avg Critic: -44.0882
# Epoch [127/300] Critic: -50.2405  Gen: 14.6801  Avg Critic: -43.6777
# Epoch [128/300] Critic: -57.0953  Gen: 47.2481  Avg Critic: -47.0047
# Epoch [129/300] Critic: -55.2377  Gen: 70.7299  Avg Critic: -47.3894
# Epoch [130/300] Critic: -50.1760  Gen: 30.9544  Avg Critic: -47.9058
# Epoch [131/300] Critic: -43.9893  Gen: 42.3204  Avg Critic: -46.9807
# Epoch [132/300] Critic: -49.0425  Gen: 56.6596  Avg Critic: -46.0787
# Epoch [133/300] Critic: -34.4916  Gen: 60.7016  Avg Critic: -47.9662
# Epoch [134/300] Critic: -41.1057  Gen: 67.1790  Avg Critic: -46.0980
# Epoch [135/300] Critic: -45.6924  Gen: 65.9146  Avg Critic: -42.1876
# Epoch [136/300] Critic: -37.8398  Gen: 70.7887  Avg Critic: -41.7885
# Epoch [137/300] Critic: -35.1000  Gen: 63.5662  Avg Critic: -43.7529
# Epoch [138/300] Critic: -71.6593  Gen: 59.4674  Avg Critic: -43.1318
# Epoch [139/300] Critic: -59.8176  Gen: 45.5599  Avg Critic: -47.3096
# Epoch [140/300] Critic: -48.4361  Gen: 69.0236  Avg Critic: -49.4743
# Epoch [141/300] Critic: -42.9824  Gen: 62.8649  Avg Critic: -46.4053
# Epoch [142/300] Critic: -44.0871  Gen: 17.5943  Avg Critic: -45.5444
# Epoch [143/300] Critic: -37.6680  Gen: 43.3588  Avg Critic: -43.4963
# Epoch [144/300] Critic: -31.5885  Gen: 57.4259  Avg Critic: -45.6823
# Epoch [145/300] Critic: -39.4686  Gen: 49.3931  Avg Critic: -44.0549
# Epoch [146/300] Critic: -49.0073  Gen: 41.3096  Avg Critic: -49.8923
# Epoch [147/300] Critic: -52.5844  Gen: 51.2553  Avg Critic: -48.5640
# Epoch [148/300] Critic: -43.2493  Gen: 64.1919  Avg Critic: -47.8062
# Epoch [149/300] Critic: -48.9254  Gen: 79.4981  Avg Critic: -45.2756
# Epoch [150/300] Critic: -60.7442  Gen: 47.0733  Avg Critic: -46.5664
# Epoch [151/300] Critic: -40.2338  Gen: 48.8734  Avg Critic: -43.9003
# Epoch [152/300] Critic: -43.7626  Gen: 53.1802  Avg Critic: -45.7841
# Epoch [153/300] Critic: -45.5579  Gen: 58.0134  Avg Critic: -42.5053
# Epoch [154/300] Critic: -39.6678  Gen: 42.4970  Avg Critic: -45.6372
# Epoch [155/300] Critic: -29.2017  Gen: 63.3726  Avg Critic: -48.7155
# Epoch [156/300] Critic: -39.6681  Gen: 60.2791  Avg Critic: -40.7467
# Epoch [157/300] Critic: -53.7528  Gen: 51.0774  Avg Critic: -45.7113
# Epoch [158/300] Critic: -36.6334  Gen: 51.0453  Avg Critic: -42.6767
# Epoch [159/300] Critic: -55.5460  Gen: 65.9406  Avg Critic: -49.0830
# Epoch [160/300] Critic: -41.2102  Gen: 53.7284  Avg Critic: -46.6183
# Epoch [161/300] Critic: -40.3342  Gen: 81.3961  Avg Critic: -47.5343
# Epoch [162/300] Critic: -41.0220  Gen: 57.0432  Avg Critic: -45.1176
# Epoch [163/300] Critic: -36.3820  Gen: 73.7160  Avg Critic: -42.7320
# Epoch [164/300] Critic: -39.9915  Gen: 61.7517  Avg Critic: -46.2594
# Epoch [165/300] Critic: -36.7058  Gen: 59.1356  Avg Critic: -45.4937
# Epoch [166/300] Critic: -55.9706  Gen: 49.2688  Avg Critic: -42.8803
# Epoch [167/300] Critic: -44.5771  Gen: 36.8419  Avg Critic: -43.6365
# Epoch [168/300] Critic: -60.8452  Gen: 50.8500  Avg Critic: -44.1416
# Epoch [169/300] Critic: -42.6059  Gen: 61.9072  Avg Critic: -42.9178
# Epoch [170/300] Critic: -43.0843  Gen: 56.9866  Avg Critic: -43.9804
# Epoch [171/300] Critic: -41.1928  Gen: 57.7378  Avg Critic: -41.4425
# Epoch [172/300] Critic: -43.6547  Gen: 49.3800  Avg Critic: -40.7234
# Epoch [173/300] Critic: -50.1491  Gen: 53.1504  Avg Critic: -47.5394
# Epoch [174/300] Critic: -56.6253  Gen: 62.3178  Avg Critic: -45.5873
# Epoch [175/300] Critic: -42.6941  Gen: 65.8136  Avg Critic: -42.7270
# Epoch [176/300] Critic: -49.8242  Gen: 59.4817  Avg Critic: -45.8961
# Epoch [177/300] Critic: -38.2139  Gen: 46.2894  Avg Critic: -40.6492
# Epoch [178/300] Critic: -44.2265  Gen: 55.2693  Avg Critic: -43.4527
# Epoch [179/300] Critic: -41.9220  Gen: 61.9883  Avg Critic: -48.0981
# Epoch [180/300] Critic: -44.7249  Gen: 66.4308  Avg Critic: -43.1005
#   -> Checkpoint saved at epoch 180 (critic loss: -43.1005)
# Epoch [181/300] Critic: -39.8016  Gen: 54.4735  Avg Critic: -40.7196
# Epoch [182/300] Critic: -41.0971  Gen: 50.1989  Avg Critic: -46.2898
# Epoch [183/300] Critic: -39.6117  Gen: 64.5280  Avg Critic: -45.7460
# Epoch [184/300] Critic: -38.1565  Gen: 46.6206  Avg Critic: -42.4377
# Epoch [185/300] Critic: -46.8779  Gen: 58.6838  Avg Critic: -45.0641
# Epoch [186/300] Critic: -36.0985  Gen: 68.2284  Avg Critic: -43.2572
# Epoch [187/300] Critic: -48.6027  Gen: 53.9732  Avg Critic: -44.2149
# Epoch [188/300] Critic: -30.7232  Gen: 68.8083  Avg Critic: -39.4496
# Epoch [189/300] Critic: -69.3724  Gen: 63.8223  Avg Critic: -44.6971
# Epoch [190/300] Critic: -51.2884  Gen: 68.8834  Avg Critic: -42.3337
#   -> Checkpoint saved at epoch 190 (critic loss: -42.3337)
# Epoch [191/300] Critic: -34.3864  Gen: 45.1955  Avg Critic: -39.7645
# Epoch [192/300] Critic: -58.6816  Gen: 43.2936  Avg Critic: -46.4940
# Epoch [193/300] Critic: -33.0682  Gen: 48.2258  Avg Critic: -45.8049
# Epoch [194/300] Critic: -46.3800  Gen: 52.6852  Avg Critic: -41.2123
# Epoch [195/300] Critic: -31.3039  Gen: 63.4502  Avg Critic: -41.1588
# Epoch [196/300] Critic: -54.6822  Gen: 51.2277  Avg Critic: -42.7022
# Epoch [197/300] Critic: -51.4184  Gen: 58.0754  Avg Critic: -45.0897
# Epoch [198/300] Critic: -41.4568  Gen: 70.8543  Avg Critic: -41.0090
# Epoch [199/300] Critic: -35.6327  Gen: 62.5432  Avg Critic: -42.1587
# Epoch [200/300] Critic: -40.3085  Gen: 56.8970  Avg Critic: -43.7808
# Epoch [201/300] Critic: -62.1291  Gen: 59.5086  Avg Critic: -43.4653
# Epoch [202/300] Critic: -59.4802  Gen: 64.4170  Avg Critic: -43.6349
# Epoch [203/300] Critic: -46.6844  Gen: 73.0547  Avg Critic: -42.8205
# Epoch [204/300] Critic: -45.4017  Gen: 50.0000  Avg Critic: -42.6057
# Epoch [205/300] Critic: -33.0462  Gen: 53.8034  Avg Critic: -40.0220
# Epoch [206/300] Critic: -28.2900  Gen: 60.1313  Avg Critic: -43.5014
# Epoch [207/300] Critic: -39.1612  Gen: 54.2863  Avg Critic: -45.1996
# Epoch [208/300] Critic: -56.5143  Gen: 57.1886  Avg Critic: -44.8350
# Epoch [209/300] Critic: -37.3106  Gen: 48.1241  Avg Critic: -39.5123
# Epoch [210/300] Critic: -31.0577  Gen: 53.6159  Avg Critic: -43.2020
# Epoch [211/300] Critic: -27.9479  Gen: 62.7456  Avg Critic: -43.9845
# Epoch [212/300] Critic: -34.1756  Gen: 64.1076  Avg Critic: -41.1522
# Epoch [213/300] Critic: -54.5709  Gen: 65.8255  Avg Critic: -43.0271
# Epoch [214/300] Critic: -40.2703  Gen: 66.2747  Avg Critic: -40.5226
# Epoch [215/300] Critic: -26.3700  Gen: 59.1272  Avg Critic: -43.3164
# Epoch [216/300] Critic: -38.6895  Gen: 57.0749  Avg Critic: -44.1513
# Epoch [217/300] Critic: -45.7493  Gen: 62.0368  Avg Critic: -41.7097
# Epoch [218/300] Critic: -28.5859  Gen: 65.3106  Avg Critic: -31.5874
# Epoch [219/300] Critic: -49.5014  Gen: 55.0448  Avg Critic: -41.3717
# Epoch [220/300] Critic: -48.7352  Gen: 54.7814  Avg Critic: -44.3507
# Epoch [221/300] Critic: -56.1149  Gen: 71.1020  Avg Critic: -44.9436
# Epoch [222/300] Critic: -32.8196  Gen: 70.3116  Avg Critic: -39.8809
# Epoch [223/300] Critic: -42.0993  Gen: 59.4355  Avg Critic: -43.1208
# Epoch [224/300] Critic: -33.8765  Gen: 62.7700  Avg Critic: -41.1697
# Epoch [225/300] Critic: -34.5935  Gen: 65.9470  Avg Critic: -40.2086
# Epoch [226/300] Critic: -49.9100  Gen: 58.4400  Avg Critic: -35.8788
# Epoch [227/300] Critic: -34.5974  Gen: 49.6406  Avg Critic: -43.8535
# Epoch [228/300] Critic: -35.3050  Gen: 63.8906  Avg Critic: -38.9838
# Epoch [229/300] Critic: -28.9663  Gen: 54.5776  Avg Critic: -43.4674
# Epoch [230/300] Critic: -42.9301  Gen: 62.0651  Avg Critic: -45.2662
# Epoch [231/300] Critic: -42.5162  Gen: 47.2449  Avg Critic: -41.2711
# Epoch [232/300] Critic: -39.5075  Gen: 55.0941  Avg Critic: -42.5374
# Epoch [233/300] Critic: -46.8927  Gen: 53.5680  Avg Critic: -46.5945
# Epoch [234/300] Critic: -55.5722  Gen: 58.1504  Avg Critic: -43.5709
# Epoch [235/300] Critic: -54.7947  Gen: 54.1479  Avg Critic: -43.1483
# Epoch [236/300] Critic: -40.1426  Gen: 54.3247  Avg Critic: -47.1137
# Epoch [237/300] Critic: -54.8286  Gen: 65.5649  Avg Critic: -47.1031
# Epoch [238/300] Critic: -48.9764  Gen: 64.2431  Avg Critic: -38.9817
# Epoch [239/300] Critic: -42.3480  Gen: 68.8018  Avg Critic: -43.2188
# Epoch [240/300] Critic: -35.5776  Gen: 63.0262  Avg Critic: -40.9999
#   -> Checkpoint saved at epoch 240 (critic loss: -40.9999)
# Epoch [241/300] Critic: -26.1837  Gen: 60.5266  Avg Critic: -43.7349
# Epoch [242/300] Critic: -38.7658  Gen: 58.8996  Avg Critic: -40.8123
# Epoch [243/300] Critic: -41.4272  Gen: 67.1567  Avg Critic: -41.7907
# Epoch [244/300] Critic: -55.9739  Gen: 62.4672  Avg Critic: -40.1836
# Epoch [245/300] Critic: -31.8662  Gen: 60.1111  Avg Critic: -45.2380
# Epoch [246/300] Critic: -31.4710  Gen: 47.4731  Avg Critic: -39.8120
# Epoch [247/300] Critic: -26.3281  Gen: 57.1666  Avg Critic: -40.6645
# Epoch [248/300] Critic: -45.6863  Gen: 50.3282  Avg Critic: -41.2936
# Epoch [249/300] Critic: -39.7567  Gen: 44.8895  Avg Critic: -40.8672
# Epoch [250/300] Critic: -49.1454  Gen: 57.3227  Avg Critic: -43.6888
# Epoch [251/300] Critic: -35.9781  Gen: 63.1799  Avg Critic: -41.6819
# Epoch [252/300] Critic: -46.9450  Gen: 55.0411  Avg Critic: -45.7398
# Epoch [253/300] Critic: -55.1385  Gen: 62.8241  Avg Critic: -45.4032
# Epoch [254/300] Critic: -46.0126  Gen: 63.4011  Avg Critic: -43.9568
# Epoch [255/300] Critic: -42.0865  Gen: 65.3548  Avg Critic: -44.8965
# Epoch [256/300] Critic: -65.6085  Gen: 75.4633  Avg Critic: -41.3841
# Epoch [257/300] Critic: -47.4466  Gen: 61.6726  Avg Critic: -45.1510
# Epoch [258/300] Critic: -35.0599  Gen: 69.4646  Avg Critic: -41.0416
# Epoch [259/300] Critic: -39.9348  Gen: 67.4148  Avg Critic: -41.9344
# Epoch [260/300] Critic: -37.2070  Gen: 64.3130  Avg Critic: -37.6935
#   -> Checkpoint saved at epoch 260 (critic loss: -37.6935)
# Epoch [261/300] Critic: -40.1681  Gen: 49.7187  Avg Critic: -41.3709
# Epoch [262/300] Critic: -61.9485  Gen: 43.0264  Avg Critic: -45.3903
# Epoch [263/300] Critic: -34.9844  Gen: 54.1559  Avg Critic: -43.8706
# Epoch [264/300] Critic: -30.5742  Gen: 60.7560  Avg Critic: -45.2218
# Epoch [265/300] Critic: -54.3148  Gen: 58.3316  Avg Critic: -42.7910
# Epoch [266/300] Critic: -72.5755  Gen: 68.3753  Avg Critic: -50.3576
# Epoch [267/300] Critic: -49.2538  Gen: 47.4259  Avg Critic: -42.5064
# Epoch [268/300] Critic: -42.3062  Gen: 66.5041  Avg Critic: -47.0459
# Epoch [269/300] Critic: -60.1244  Gen: 74.4739  Avg Critic: -44.7394
# Epoch [270/300] Critic: -32.6141  Gen: 66.6474  Avg Critic: -37.4839
#   -> Checkpoint saved at epoch 270 (critic loss: -37.4839)
# Epoch [271/300] Critic: -54.8290  Gen: 60.2166  Avg Critic: -43.4045
# Epoch [272/300] Critic: -30.4260  Gen: 65.0773  Avg Critic: -47.1835
# Epoch [273/300] Critic: -52.2875  Gen: 58.4974  Avg Critic: -42.9633
# Epoch [274/300] Critic: -27.1043  Gen: 60.6816  Avg Critic: -41.0439
# Epoch [275/300] Critic: -46.6418  Gen: 69.3425  Avg Critic: -46.8838
# Epoch [276/300] Critic: -48.2793  Gen: 69.0083  Avg Critic: -42.2730
# Epoch [277/300] Critic: -31.7943  Gen: 64.1606  Avg Critic: -43.6476
# Epoch [278/300] Critic: -37.7149  Gen: 66.0962  Avg Critic: -46.4028
# Epoch [279/300] Critic: -52.2941  Gen: 77.3509  Avg Critic: -40.4140
# Epoch [280/300] Critic: -40.0018  Gen: 67.6808  Avg Critic: -44.2914
# Epoch [281/300] Critic: -38.7400  Gen: 66.8821  Avg Critic: -40.2582
# Epoch [282/300] Critic: -37.3124  Gen: 70.3635  Avg Critic: -43.1646
# Epoch [283/300] Critic: -28.9692  Gen: 71.6357  Avg Critic: -35.5495
# Epoch [284/300] Critic: -38.6603  Gen: 56.7971  Avg Critic: -46.6040
# Epoch [285/300] Critic: -34.5737  Gen: 65.3979  Avg Critic: -40.2885
# Epoch [286/300] Critic: -42.2387  Gen: 58.1511  Avg Critic: -46.0137
# Epoch [287/300] Critic: -40.3655  Gen: 78.9091  Avg Critic: -41.9783
# Epoch [288/300] Critic: -35.6592  Gen: 63.6901  Avg Critic: -36.1980
# Epoch [289/300] Critic: -57.2051  Gen: 57.7495  Avg Critic: -44.8655
# Epoch [290/300] Critic: -62.6352  Gen: 69.6437  Avg Critic: -45.0700
# Epoch [291/300] Critic: -42.0278  Gen: 64.9358  Avg Critic: -40.2472
# Epoch [292/300] Critic: -31.2810  Gen: 68.0842  Avg Critic: -36.7226
# Epoch [293/300] Critic: -39.7458  Gen: 67.3580  Avg Critic: -41.6138
# Epoch [294/300] Critic: -35.9536  Gen: 62.7273  Avg Critic: -37.0330
# Epoch [295/300] Critic: -40.8382  Gen: 71.4736  Avg Critic: -41.9841
# Epoch [296/300] Critic: -33.0488  Gen: 68.2266  Avg Critic: -41.0157
# Epoch [297/300] Critic: -35.4234  Gen: 69.0674  Avg Critic: -41.9785
# Epoch [298/300] Critic: -24.4231  Gen: 59.7479  Avg Critic: -41.7501
# Epoch [299/300] Critic: -34.6566  Gen: 64.9146  Avg Critic: -42.3996
# Epoch [300/300] Critic: -28.4104  Gen: 68.3978  Avg Critic: -42.8976
# Training complete.
# 200 images saved to generated_images/
# Sample grid saved.
